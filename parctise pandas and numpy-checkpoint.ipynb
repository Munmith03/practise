# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
a=np.array([[45.1,334.],[42.3,555.0],[67,89.7],[5.1,6.5],[32,65]],dtype='int32').reshape(5,2)
a
# Out:
# array([[ 45, 334],
#        [ 42, 555],
#        [ 67,  89],
#        [  5,   6],
#        [ 32,  65]])

# %%
a=np.array([np.nan,1,2,np.nan,6,7,8])
a
# Out:
# array([nan,  1.,  2., nan,  6.,  7.,  8.])

# %%
a[~np.isnan(a)]
# Out:
# array([1., 2., 6., 7., 8.])

# %%
np.random.random((2,3,4))
# Out:
# array([[[0.39531585, 0.37979256, 0.82901703, 0.50436637],
#         [0.37498564, 0.56530602, 0.4962913 , 0.83930826],
#         [0.02717783, 0.31852041, 0.17706806, 0.89062044]],
#
#        [[0.21490561, 0.4462926 , 0.8832924 , 0.47571675],
#         [0.52307277, 0.61151132, 0.46496667, 0.18797673],
#         [0.73514447, 0.63290591, 0.87161512, 0.13250178]]])

# %%
np.random.rand(4)
# Out:
# array([0.44713612, 0.7013295 , 0.78258185, 0.65945299])

# %%
np.random.randn(4)
# Out:
# array([ 0.35006878, -0.27929212,  0.92534768,  1.10398653])

# %%
a=np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
print('Array*3:\n',a*3)
# Out:
# Array*3:
#  [3 6 9]

# %%
import numpy as np
a = np.array([1+1j, 1+0j, 4.5, 3, 2, 2j])
print("Original array")
print(a)
print("Checking for complex number:")
print(np.iscomplex(a))
print("Checking for real number:")
print(np.isreal(a))
print("Checking for scalar type:")
print(np.isscalar(3.1))
print(np.isscalar([3.1]))
# Out:
# Original array
# [1. +1.j 1. +0.j 4.5+0.j 3. +0.j 2. +0.j 0. +2.j]
# Checking for complex number:
# [ True False False False False  True]
# Checking for real number:
# [False  True  True  True  True False]
# Checking for scalar type:
# True
# False

# %%
y=np.random.randint(2,5,4)
y
# Out:
# array([4, 3, 2, 4])

# %%
#pandas

# %%
import pandas as pd

# %%
a=pd.Series([1,2,3,4])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
a=pd.Series([11.1,12.3,13.5,14.4],index=[1,2,3,4],dtype='float64')
a
# Out:
# 1    11.1
# 2    12.3
# 3    13.5
# 4    14.4
# dtype: float64

# %%
print(a[1:3])
# Out:
# 2    12.3
# 3    13.5
# dtype: float64

# %%
print(a[-2:])
# Out:
# 3    13.5
# 4    14.4
# dtype: float64

# %%
data=np.array([1,2,3,4])
p=pd.Series(data)
p
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
a={'Name':'x','Age':12}
p=pd.Series(a)
p
# Out:
# Name     x
# Age     12
# dtype: object

# %%
data=np.array(['a','b','c','d'])
a=pd.Series(data,index=[0,1,2,3])
a
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data=[1,2,3,4]
df=pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
data=(['Alex',10],['Bob',12],['Clarke',13])
df=pd.DataFrame(data,columns=['Name','Age'],dtype='float64')
df
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0

# %%
data=(['Alex',10],['Bob',12],['Clarke',13])
df=pd.DataFrame(data,columns=['Name','Age'],index=[1,2,3],dtype='int32')
df
# Out:
#      Name  Age
# 1    Alex   10
# 2     Bob   12
# 3  Clarke   13

# %%
data={'Name':['Tom','Jack','Steve','Rocky'],'Age':[26,34,21,42]}
pd=pd.DataFrame(data)
pd
# Out:
#     Name  Age
# 0    Tom   26
# 1   Jack   34
# 2  Steve   21
# 3  Rocky   42

# %%
data=(['Akex',10.2,'A'],['Bob',12.5,'B'],['Clarke',15.7,'C'])
df=pd.DataFrame(data,index=[1,2,3],columns=['Name','Age','Division'],dtype='int64')
df
# Out:
#      Name   Age Division
# 1    Akex  10.2        A
# 2     Bob  12.5        B
# 3  Clarke  15.7        C

# %%
data=({'a':1,'b':2},{'a':5,'b':10,'c':20})
df=pd.DataFrame(data,dtype=float,index=['First','Second'],columns=['ea','b','c'])
df
# Out:
#         ea     b     c
# First  NaN   2.0   NaN
# Second NaN  10.0  20.0

# %%
data=({'a':1,'b':2},{'a':5,'b':10,'c':20})
df1=pd.DataFrame(data,index=['First','Second'],columns=['a','b'])
df2=pd.DataFrame(data,index=['First','Second'],columns=['a','b','c'])
print(df1)
print('\n')
print(df2)
# Out:
#         a   b
# First   1   2
# Second  5  10
#
#
#         a   b     c
# First   1   2   NaN
# Second  5  10  20.0

# %%
df3=df1.append(df2)
print(df3)
# Out:
#         a   b     c
# First   1   2   NaN
# Second  5  10   NaN
# First   1   2   NaN
# Second  5  10  20.0

# %%
df1=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df3=df1.append(df2)
print(df3)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.random((8,4)),index=[1,2,3,4,5,6,7,8],columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 1  0.130220  0.899445  0.877055  0.937567
# 2  0.769724  0.898280  0.509074  0.545266
# 3  0.682852  0.536993  0.432405  0.593138
# 4  0.039876  0.653056  0.977695  0.056201
# 5  0.487617  0.053085  0.200801  0.109484
# 6  0.664087  0.798984  0.604799  0.999993
# 7  0.499647  0.886495  0.861531  0.549223
# 8  0.688107  0.055603  0.570602  0.183696

# %%
df.iloc[2:8,-4:-1]
# Out:
#           A         B         C
# 3  0.682852  0.536993  0.432405
# 4  0.039876  0.653056  0.977695
# 5  0.487617  0.053085  0.200801
# 6  0.664087  0.798984  0.604799
# 7  0.499647  0.886495  0.861531
# 8  0.688107  0.055603  0.570602

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.301919  0.282758  0.205898  0.332324
# 1  0.450081  0.371351  0.205599  0.047955
# 2  0.392999  0.321717  0.390909  0.937324
# 3  0.585101  0.959104  0.277533  0.382460
# 4  0.951097  0.805554  0.920690  0.932599
# 5  0.230337  0.489902  0.599809  0.824207
# 6  0.733275  0.040434  0.378525  0.437405
# 7  0.241868  0.613756  0.124469  0.666981
# 8  0.071494  0.219430  0.629989  0.865492
# 9  0.200289  0.389300  0.397211  0.645044

# %%
df.plot.scatter(x='b',y='a')

# %%
data={'subjectid':[1,2,3,4,5],'firstname':['Jack','Sam','Ram','Mary','Alex'],
                 'lastname':['ali','anderson','denzil','dsouza','dsa']}
df1=pd.DataFrame(data,columns=['subjectid','firstname','lastname'])
df1
# Out:
#    subjectid firstname  lastname
# 0          1      Jack       ali
# 1          2       Sam  anderson
# 2          3       Ram    denzil
# 3          4      Mary    dsouza
# 4          5      Alex       dsa

# %%
data={'subjectid':[4,5,6,7,8],
         'firstname':['Billy','Brian','Bran','Bryce','Betty'],
         'lastname':['Bonder','Black','Balwner','Brice','Btisan']}
df2=pd.DataFrame(data,columns=['subjectid','firstname','lastname'])
df2
# Out:
#    subjectid firstname lastname
# 0          4     Billy   Bonder
# 1          5     Brian    Black
# 2          6      Bran  Balwner
# 3          7     Bryce    Brice
# 4          8     Betty   Btisan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings                                                   # import

# %%
data=pd.read_csv('hrdata.csv')                                 #yes
print(data)
# Out:
#              Name  HireData    Salary  SickDayremaining
# 0  Graham Chapman  03/15/14   50000.0                10
# 1     John Cleese  06/01/15   65000.0                 8
# 2       Eric Idle  05/12/14   45000.0                10
# 3     Terry Jones  11/01/13   70000.0                 3
# 4   Terry Gilliam  08/12/14   48000.0                 7
# 5   Michael Palin  05/23/13  660000.0                 8

# %%
data.describe()                                                        #y
# Out:
#               Salary  SickDayremaining
# count       6.000000          6.000000
# mean   156333.333333          7.666667
# std    246946.687904          2.581989
# min     45000.000000          3.000000
# 25%     48500.000000          7.250000
# 50%     57500.000000          8.000000
# 75%     68750.000000          9.500000
# max    660000.000000         10.000000

# %%
data=pd.read_csv('hrdata.csv',parse_dates=['HireData'])                          #y
print(data)
# Out:
#              Name   HireData    Salary  SickDayremaining
# 0  Graham Chapman 2014-03-15   50000.0                10
# 1     John Cleese 2015-06-01   65000.0                 8
# 2       Eric Idle 2014-05-12   45000.0                10
# 3     Terry Jones 2013-11-01   70000.0                 3
# 4   Terry Gilliam 2014-08-12   48000.0                 7
# 5   Michael Palin 2013-05-23  660000.0                 8

# %%
data=pd.read_csv('hrdata.csv',index_col='Name',parse_dates=['HireData'])           #y
print(data)
# Out:
#                  HireData    Salary  SickDayremaining
# Name
# Graham Chapman 2014-03-15   50000.0                10
# John Cleese    2015-06-01   65000.0                 8
# Eric Idle      2014-05-12   45000.0                10
# Terry Jones    2013-11-01   70000.0                 3
# Terry Gilliam  2014-08-12   48000.0                 7
# Michael Palin  2013-05-23  660000.0                 8

# %%
print(type(data['HireData'][0]))                                                #y
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(type(data['HireData'][2]))                                            #y
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
data=pd.read_csv('hrdata.csv',header=0,names=['Employees','Hired','Salary','Sickday'])   #changes in the header colums
data
# Out:
#         Employees     Hired    Salary  Sickday
# 0  Graham Chapman  03/15/14   50000.0       10
# 1     John Cleese  06/01/15   65000.0        8
# 2       Eric Idle  05/12/14   45000.0       10
# 3     Terry Jones  11/01/13   70000.0        3
# 4   Terry Gilliam  08/12/14   48000.0        7
# 5   Michael Palin  05/23/13  660000.0        8

# %%
data=pd.read_csv('hrdata.csv',index_col='Employees',parse_dates=['Hired'],header=0,names=['Employees','Hired','Salary','Sickday'])
data
# Out:
#                     Hired    Salary  Sickday
# Employees
# Graham Chapman 2014-03-15   50000.0       10
# John Cleese    2015-06-01   65000.0        8
# Eric Idle      2014-05-12   45000.0       10
# Terry Jones    2013-11-01   70000.0        3
# Terry Gilliam  2014-08-12   48000.0        7
# Michael Palin  2013-05-23  660000.0        8

# %%
print(type(data['Employees']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data
# Out:
#                     Hired    Salary  Sickday
# Employees
# Graham Chapman 2014-03-15   50000.0       10
# John Cleese    2015-06-01   65000.0        8
# Eric Idle      2014-05-12   45000.0       10
# Terry Jones    2013-11-01   70000.0        3
# Terry Gilliam  2014-08-12   48000.0        7
# Michael Palin  2013-05-23  660000.0        8

# %%
pd.read_csv('hrdata.csv')
# Out:
#              Name  HireData    Salary  SickDayremaining
# 0  Graham Chapman  03/15/14   50000.0                10
# 1     John Cleese  06/01/15   65000.0                 8
# 2       Eric Idle  05/12/14   45000.0                10
# 3     Terry Jones  11/01/13   70000.0                 3
# 4   Terry Gilliam  08/12/14   48000.0                 7
# 5   Michael Palin  05/23/13  660000.0                 8

# %%
data.to_csv('hrdata1_modified.csv')          #y

# %%
df=pd.read_csv('hrdata1_modified.csv')             #y
df
# Out:
#         Employees       Hired    Salary  Sickday
# 0  Graham Chapman  2014-03-15   50000.0       10
# 1     John Cleese  2015-06-01   65000.0        8
# 2       Eric Idle  2014-05-12   45000.0       10
# 3     Terry Jones  2013-11-01   70000.0        3
# 4   Terry Gilliam  2014-08-12   48000.0        7
# 5   Michael Palin  2013-05-23  660000.0        8

# %%
df['Salary'].plot.bar()                #y

# %%
df['Sickday'].plot.bar()

# %%
data=pd.read_csv('empl.csv')
print(data)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
data=pd.read_csv('empl16oct.csv')                   #y create modified data
data
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 1     2     Lee  31.0    Edmonto   Canada   3900.0      06/01/15
# 2     3    Dave  34.0    Toronto   Canada   8000.0      05/12/14
# 3     4    Anik  26.0   HongKong     Asia  66672.0      11/01/13
# 4     5   kamal  30.0        NaN  America      NaN      08/12/14
# 5     6    Geet   NaN   HongKong     Asia  30007.0      05/23/13
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# ...

# %%
data=pd.read_csv('empl16oct.csv',index_col='SrNo',parse_dates=['Dateofjoining'],header=0,names=['SrNo','Employees','Age','City','Country','Salary','Dateofjoining'])
data
# Out:
#      Employees   Age       City  Country   Salary Dateofjoining
# SrNo
# 1          Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 2          Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 3         Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 4         Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 5        kamal  30.0        NaN  America      NaN    2014-08-12
# 6         Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 7       Steven  43.0    BayArea  America   8300.0    2019-07-27
# 8          Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 9         hari  50.0    newyork  America  67666.0    2045-01-06
# 11        yami   NaN    newyork  America   8888.0    2052-05-15
# 12        Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 13       kamal  30.0        NaN  America  34344.0    1978-08-05
# 14        Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# 15      Steven  43.0        NaN  America   8300.0    1983-03-20
# ...

# %%
data['Age'].plot.bar()

# %%
data['Salary'].min()
# Out:
# 3900.0

# %%
data
# Out:
#      Employees   Age       City  Country   Salary Dateofjoining
# SrNo
# 1          Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 2          Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 3         Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 4         Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 5        kamal  30.0        NaN  America      NaN    2014-08-12
# 6         Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 7       Steven  43.0    BayArea  America   8300.0    2019-07-27
# 8          Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 9         hari  50.0    newyork  America  67666.0    2045-01-06
# 11        yami   NaN    newyork  America   8888.0    2052-05-15
# 12        Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 13       kamal  30.0        NaN  America  34344.0    1978-08-05
# 14        Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# 15      Steven  43.0        NaN  America   8300.0    1983-03-20
# ...

# %%
data=pd.read_csv('empl16oct.csv',parse_dates=['Dateofjoining'],dtype={'Salary':np.float64})
data
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 1     2     Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 2     3    Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 3     4    Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 4     5   kamal  30.0        NaN  America      NaN    2014-08-12
# 5     6    Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 6     7  Steven  43.0    BayArea  America   8300.0    2019-07-27
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 8     9    hari  50.0    newyork  America  67666.0    2045-01-06
# 9    11    yami   NaN    newyork  America   8888.0    2052-05-15
# 10   12    Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 11   13   kamal  30.0        NaN  America  34344.0    1978-08-05
# 12   14    Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# ...

# %%
data['Salary'].max()
# Out:
# 67666.0

# %%
data['Salary'].min()
# Out:
# 3900.0

# %%
data['Salary'].plot()

# %%
print(data.loc[1:5,['SNo','Dateofjoining']])
# Out:
#    SNo Dateofjoining
# 1    2    2015-06-01
# 2    3    2014-05-12
# 3    4    2013-11-01
# 4    5    2014-08-12
# 5    6    2013-05-23

# %%
data.loc[1:5,'SNo':'City']
# Out:
#    SNo   Name   Age      City
# 1    2    Lee  31.0   Edmonto
# 2    3   Dave  34.0   Toronto
# 3    4   Anik  26.0  HongKong
# 4    5  kamal  30.0       NaN
# 5    6   Geet   NaN  HongKong

# %%
data.loc[1:5,'Salary']
# Out:
# 1     3900.0
# 2     8000.0
# 3    66672.0
# 4        NaN
# 5    30007.0
# Name: Salary, dtype: float64

# %%
data.iloc[:,0:3]
# Out:
#     SNo    Name   Age
# 0     1     Tom  28.0
# 1     2     Lee  31.0
# 2     3    Dave  34.0
# 3     4    Anik  26.0
# 4     5   kamal  30.0
# 5     6    Geet   NaN
# 6     7  Steven  43.0
# 7     8     Ram  38.0
# 8     9    hari  50.0
# 9    11    yami   NaN
# 10   12    Anik  26.0
# 11   13   kamal  30.0
# 12   14    Geet  22.0
# 13   15  Steven  43.0
# 14   16     Ram  38.0
# 15   17    hari   NaN
# 16   18    yami  27.0
# 17   19     Lee  31.0
# 18   20  Andrew  34.0
# 19   21   soham  32.0
# 20   22    Grig  26.0
# 21   23   Kiara  27.0

# %%
data.iloc[1:5,-5:-1]
# Out:
#     Age      City  Country   Salary
# 1  31.0   Edmonto   Canada   3900.0
# 2  34.0   Toronto   Canada   8000.0
# 3  26.0  HongKong     Asia  66672.0
# 4  30.0       NaN  America      NaN

# %%
data.loc[1:5,'Age':'Dateofjoining']
# Out:
#     Age      City  Country   Salary Dateofjoining
# 1  31.0   Edmonto   Canada   3900.0    2015-06-01
# 2  34.0   Toronto   Canada   8000.0    2014-05-12
# 3  26.0  HongKong     Asia  66672.0    2013-11-01
# 4  30.0       NaN  America      NaN    2014-08-12
# 5   NaN  HongKong     Asia  30007.0    2013-05-23

# %%
data['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
data['Name'].describe()
# Out:
# count        22
# unique       14
# top       kamal
# freq          2
# Name: Name, dtype: object

# %%
data.describe()
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
data
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 1     2     Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 2     3    Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 3     4    Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 4     5   kamal  30.0        NaN  America      NaN    2014-08-12
# 5     6    Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 6     7  Steven  43.0    BayArea  America   8300.0    2019-07-27
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 8     9    hari  50.0    newyork  America  67666.0    2045-01-06
# 9    11    yami   NaN    newyork  America   8888.0    2052-05-15
# 10   12    Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 11   13   kamal  30.0        NaN  America  34344.0    1978-08-05
# 12   14    Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# ...

# %%
df=pd.DataFrame(data=data)    ---changing the original varibale to df
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 1     2     Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 2     3    Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 3     4    Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 4     5   kamal  30.0        NaN  America      NaN    2014-08-12
# 5     6    Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 6     7  Steven  43.0    BayArea  America   8300.0    2019-07-27
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 8     9    hari  50.0    newyork  America  67666.0    2045-01-06
# 9    11    yami   NaN    newyork  America   8888.0    2052-05-15
# 10   12    Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 11   13   kamal  30.0        NaN  America  34344.0    1978-08-05
# 12   14    Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# ...

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 1     2     Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 2     3    Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 3     4    Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 4     5   kamal  30.0        NaN  America      NaN    2014-08-12
# 5     6    Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 6     7  Steven  43.0    BayArea  America   8300.0    2019-07-27
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 8     9    hari  50.0    newyork  America  67666.0    2045-01-06
# 9    11    yami   NaN    newyork  America   8888.0    2052-05-15
# 10   12    Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 11   13   kamal  30.0        NaN  America  34344.0    1978-08-05
# 12   14    Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# ...

# %%
print(df['Salary'].describe())
# Out:
# count       19.000000
# mean     33739.947368
# std      23151.188084
# min       3900.000000
# 25%       8888.000000
# 50%      33451.000000
# 75%      54666.000000
# max      67666.000000
# Name: Salary, dtype: float64

# %%
print(df['Name'].describe())
# Out:
# count        22
# unique       14
# top       kamal
# freq          2
# Name: Name, dtype: object

# %%
df.describe()
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0    2014-03-15
# 1     2     Lee  31.0    Edmonto   Canada   3900.0    2015-06-01
# 2     3    Dave  34.0    Toronto   Canada   8000.0    2014-05-12
# 3     4    Anik  26.0   HongKong     Asia  66672.0    2013-11-01
# 4     5   kamal  30.0        NaN  America      NaN    2014-08-12
# 5     6    Geet   NaN   HongKong     Asia  30007.0    2013-05-23
# 6     7  Steven  43.0    BayArea  America   8300.0    2019-07-27
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0    2006-11-03
# 8     9    hari  50.0    newyork  America  67666.0    2045-01-06
# 9    11    yami   NaN    newyork  America   8888.0    2052-05-15
# 10   12    Anik  26.0   HongKong     Asia  66672.0    1975-06-09
# 11   13   kamal  30.0        NaN  America  34344.0    1978-08-05
# 12   14    Geet  22.0   HongKong     Asia  30007.0    1981-11-03
# ...

# %%
df['Country'].describe()
# Out:
# count          22
# unique          5
# top       America
# freq            8
# Name: Country, dtype: object

# %%
df.columns
# Out:
# Index(['SNo', 'Name', 'Age', 'City', 'Country', 'Salary', 'Dateofjoining'], dtype='object')

# %%
df=pd.read_csv('empl16oct.csv')
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 1     2     Lee  31.0    Edmonto   Canada   3900.0      06/01/15
# 2     3    Dave  34.0    Toronto   Canada   8000.0      05/12/14
# 3     4    Anik  26.0   HongKong     Asia  66672.0      11/01/13
# 4     5   kamal  30.0        NaN  America      NaN      08/12/14
# 5     6    Geet   NaN   HongKong     Asia  30007.0      05/23/13
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# ...

# %%
df1=df.drop([14,15,16,17])
df1

# %%
df=df.drop([14,15,16,17])
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 1     2     Lee  31.0    Edmonto   Canada   3900.0      06/01/15
# 2     3    Dave  34.0    Toronto   Canada   8000.0      05/12/14
# 3     4    Anik  26.0   HongKong     Asia  66672.0      11/01/13
# 4     5   kamal  30.0        NaN  America      NaN      08/12/14
# 5     6    Geet   NaN   HongKong     Asia  30007.0      05/23/13
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# ...

# %%
df.drop([3,4,5],inplace=True)
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# 13   15  Steven  43.0        NaN  America   8300.0      03/20/83
# 18   20  Andrew  34.0      Congo   Africa  34432.0      11/07/05
# 19   21   soham  32.0     Angola   Africa  34534.0      12/12/11
# 20   22    Grig  26.0    Finland   Europe  33451.0      04/15/17
# 21   23   Kiara  27.0     London   Europe      NaN      10/12/20

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 1     2     Lee  31.0    Edmonto   Canada   3900.0      06/01/15
# 2     3    Dave  34.0    Toronto   Canada   8000.0      05/12/14
# 3     4    Anik  26.0   HongKong     Asia  66672.0      11/01/13
# 4     5   kamal  30.0        NaN  America      NaN      08/12/14
# 5     6    Geet   NaN   HongKong     Asia  30007.0      05/23/13
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# ...

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary Dateofjoining
# 0     1     Tom  28.0    Toronto   Canada  20000.0      03/15/14
# 6     7  Steven  43.0    BayArea  America   8300.0      07/27/19
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0      11/03/06
# 8     9    hari  50.0    newyork  America  67666.0      01/06/45
# 9    11    yami   NaN    newyork  America   8888.0      05/15/52
# 10   12    Anik  26.0   HongKong     Asia  66672.0      06/09/75
# 11   13   kamal  30.0        NaN  America  34344.0      08/05/78
# 12   14    Geet  22.0   HongKong     Asia  30007.0      11/03/81
# 13   15  Steven  43.0        NaN  America   8300.0      03/20/83
# 18   20  Andrew  34.0      Congo   Africa  34432.0      11/07/05
# 19   21   soham  32.0     Angola   Africa  34534.0      12/12/11
# 20   22    Grig  26.0    Finland   Europe  33451.0      04/15/17
# 21   23   Kiara  27.0     London   Europe      NaN      10/12/20

# %%
df=df.drop('Salary',axis=1)
df
# Out:
#     SNo  Country Dateofjoining
# 0     1   Canada      03/15/14
# 6     7  America      07/27/19
# 7     8     Asia      11/03/06
# 8     9  America      01/06/45
# 9    11  America      05/15/52
# 10   12     Asia      06/09/75
# 11   13  America      08/05/78
# 12   14     Asia      11/03/81
# 13   15  America      03/20/83
# 18   20   Africa      11/07/05
# 19   21   Africa      12/12/11
# 20   22   Europe      04/15/17
# 21   23   Europe      10/12/20

# %%
df.drop('Dateofjoining',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-264-3bdaee626ac5> in <module>
# ----> 1 df.drop('Dateofjoining',axis=1,inplace=True)
#       2 df
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df
